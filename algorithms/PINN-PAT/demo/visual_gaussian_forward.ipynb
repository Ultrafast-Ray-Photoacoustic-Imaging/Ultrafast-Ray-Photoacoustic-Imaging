# %% [markdown]
# #### Visualization demo of `pinn_pat_gs_init.ckpt`
#
# - Checkpoint is generated by `../run/run_gaussian_forward.py`
#
# - The PINN with gaussian-shaped initial pressure is trained for only 50000 iteration. It can be used as a pretrained model for PAT reconstruction optimization to accelerate covergence and improve  accuracy.
#
# ------

# %%
import torch
torch.set_grad_enabled(False)
import sys
from matplotlib import pyplot as plt
import json
from pprint import pprint
sys.path.append("..")


from models.pinn_for_pat import PINNForPAT
from models.arg import Arg
device = torch.device("cpu")

# %%
ckpt_filepath = "../ckpt/gaussian/pinn_pat_gs_init.ckpt"
state_dict = torch.load(ckpt_filepath, map_location=torch.device('cpu'))

arg_dict = json.loads(bytes(state_dict['arg'].numpy()).decode('utf-8'))
pprint(arg_dict)

arg = Arg.from_dict(arg_dict)
arg.load_filepath = ckpt_filepath
pinn_pat = PINNForPAT(arg, device=device)
# Out:
# {'activation': 'Sin',
#  'bc_batch_size': None,
#  'dpdt0_weight': 1e-06,
#  'fit_type': 'Forward',
#  'in_channels': 3,
#  'l_layers': 9,
#  'load_filepath': None,
#  'lr_end': 1e-05,
#  'lr_start': 0.0002,
#  'medium': 'A: Homogeneous and unlossy',
#  'n_hidden': 180,
#  'n_t': 700,
#  'num_iteration': 50000,
#  'out_channels': 1,
#  'p0_filepath': '../phantom/gaussian/gaussian_p0_100.pts',
#  'pde_batch_size': 10000,
#  'pde_weight': 1e-07,
#  'save_filepath': '../ckpt/pinn_pat_gs_0917_0848.ckpt',
#  'sensor_filepath': None,
#  't0_batch_size': 5000,
#  't_max': 1.05,
#  't_min': 0.0}
# Load: ../ckpt/gaussian/pinn_pat_gs_init.ckpt <All keys matched successfully>
#  [PINNForPAT]  {'medium': 'A: Homogeneous and unlossy', 'fit_type': 'Forward', 'in_channels': 3, 'out_channels': 1, 'n_hidden': 180, 'l_layers': 9, 'activation': 'Sin', 't_min': 0.0, 't_max': 1.05, 'n_t': 700, 'pde_batch_size': 10000, 't0_batch_size': 5000, 'bc_batch_size': None, 'p0_batch_size': None, 'pde_weight': 1e-07, 'dpdt0_weight': 1e-06, 'num_iteration': 50000, 'lr_start': 0.0002, 'lr_end': 1e-05, 'save_filepath': '../ckpt/pinn_pat_gs_0917_0848.ckpt', 'load_filepath': '../ckpt/gaussian/pinn_pat_gs_init.ckpt', 'sensor_filepath': None, 'p0_filepath': '../phantom/gaussian/gaussian_p0_100.pts'}

# %% [markdown]
# ### Pressure field evolution (0~1)

# %%
H = 256
X_axis = torch.linspace(0, 1, 2 * H + 1)[1::2]
x, y = torch.meshgrid([X_axis] * 2, indexing="ij")

fig, axes = plt.subplots(dpi=100, figsize=(20, 2), ncols=11)
list(map(lambda ax:ax.axis(False), axes.flatten()))
for it, t in enumerate(torch.linspace(0, 1, 11)):
    p0 = pinn_pat.p(torch.stack([x, y, torch.zeros_like(x) + t], dim=-1))
    if it == 0:
        vmax = max(p0.max(), 1e-5)
    axes[it].imshow(p0, cmap="bwr", vmax=vmax, vmin=-vmax)
    axes[it].set_title(f"t={t:.1f}" + r" $\rm{\mu s}$")
